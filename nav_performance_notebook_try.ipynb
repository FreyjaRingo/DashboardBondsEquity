# %%
import refinitiv.data as rd
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x1cd5f27c310 {name='workspace'}>

# %%
df = rd.get_data(
    universe = ['LP68683420'],
    fields = [
        'TR.FundNAV (SDate:0D)',
        'TR.FundNAV (SDate:0W)',
        'TR.FundNAV (SDate:0M)',
        'TR.FundNAV (SDate:-1AQ)',
        'TR.FundNAV (SDate:-2AQ)',
        'TR.FundNAV (SDate:-6AM)',
        'TR.FundNAV (SDate:-12AM)',
        'TR.FundNAV (SDate:-4AQ)',
        'TR.FundNAV (SDate:-1AY)',
        'TR.FundNAV (SDate:0CY)'
        ]
)

# %%
df.head()
# Out:
#    Instrument     NAV     NAV     NAV    NAV     NAV     NAV     NAV     NAV  \
# 0  LP68683420  545.24  532.24  581.45  682.5  819.32  819.32  775.17  775.17
#
#       NAV     NAV
# 0  775.17  791.87
